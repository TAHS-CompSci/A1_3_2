# %%
"""
A1_3_2Elkins_notes.py
Programmer:Adam 
this is the place where I put my stuff that i'm working on
"""

"""
Variables

variable > assigment operator > value or expression

varible = value/expression #assigment statement 
"""
x = 0 #acceptable nut not optinal 
num = 0 #mnemonic nomenclature is best practice 

"""
Built-in functions

these are minature programns that allow you to do more with Python without requiring YOU to do the programming.

"""

string = eval("36")

name = input("Enter your name: ")

print("Hello class!")#python 3 print function


"""
variables 

the formula is as follows 
var=value/exspression
it is known as an assigment or an exspression 
the = is a assigment oporator 
mnemonic is the name of the variables that have meaning in the programn 
variable rules:
-start with a lower case 
-or start with under score 
-can include 
    -uppercase
    -lowercase
    -numbers 
    -underscores 
NO SPACES
camel casing/ thisIsAnExample
underscore spaceing 
relational oporators
!= not equal
== equal
> greater than 
< less than
>= greater than or equal to
<= less than or equal to

exspressions
+
-
* multiply
** exponite 
/ float division 
// interger division 
% mod

def funcName([arg...])
veriables rules apply to fucntion names 
scope 1for x in range(100):
scope 2 if x =="this":
scope 3 print("that")
    else:
        print("not")
    print("done")
funcNme()

every scope or tab == 4 spaces



"""

# %%
"""
A1.3.2. coding 
Adam Elkins
this will be where i put the code from the activtiy 
"""
